# %% [markdown]
# # Preprocessing data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.colors 

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, log_loss
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook

# %%
my_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red", "yellow", "green"])
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("mobile_cleaned.csv")

# %%
PhoneId = df["PhoneId"]
Rating = df["Rating"]
df = df.drop("PhoneId", axis=1).drop("Rating", axis=1)

# %%
Rating = Rating.values

# %%
min_max_scaler = MinMaxScaler()
standard_scaler = StandardScaler()
Rating_s = min_max_scaler.fit_transform(Rating.reshape(-1,1))
threshold = 4.1
threshold_s = min_max_scaler.transform(np.array(threshold).reshape(-1,1))
Rating_b = list(map(lambda x:0 if x<threshold_s else 1, Rating_s))

# %% [markdown]
# # Train-test split

# %%
X_train, X_val, Y_train, Y_val = train_test_split(df, Rating, stratify=Rating_b, test_size=0.25)

# %%
X_train_s = standard_scaler.fit_transform(X_train)
X_val_s = standard_scaler.transform(X_val)
Y_train_s = min_max_scaler.transform(Y_train.reshape(-1,1))
Y_val_s = min_max_scaler.transform(Y_val.reshape(-1,1))
Y_train_b = list(map(lambda x:0 if x<threshold_s else 1, Y_train_s))
Y_val_b = list(map(lambda x:0 if x<threshold_s else 1, Y_val_s))

# %%
df.describe()
# Out:
#        Pixel Density  Screen Size  ...     Sim1_3G     Sim1_4G
# count     341.000000   341.000000  ...  341.000000  341.000000
# mean      344.211144     5.462317  ...    0.020528    0.958944
# std        88.161129     0.742529  ...    0.142006    0.198711
# min       143.000000     2.400000  ...    0.000000    0.000000
# 25%       282.000000     5.200000  ...    0.000000    1.000000
# 50%       326.000000     5.500000  ...    0.000000    1.000000
# 75%       403.000000     6.000000  ...    0.000000    1.000000
# max       576.000000     6.590000  ...    1.000000    1.000000
#
# [8 rows x 86 columns]

# %% [markdown]
# # Feed Forward Neural network class

# %%
class FFSN_MultiClass:
  
  def __init__(self, n_inputs, n_outputs, hidden_sizes=[3]):
    self.nx = n_inputs
    self.ny = n_outputs
    self.nh = len(hidden_sizes)
    self.sizes = [self.nx] + hidden_sizes + [self.ny] 

    self.W = {}
    self.B = {}
    for i in range(self.nh+1):
      self.W[i+1] = np.random.randn(self.sizes[i], self.sizes[i+1])
      self.B[i+1] = np.zeros((1, self.sizes[i+1]))
      
  def sigmoid(self, x):
    return 1.0/(1.0 + np.exp(-x))
  
  def softmax(self, x):
    exps = np.exp(x)
    return exps / np.sum(exps)

  def forward_pass(self, x):
    self.A = {}
    self.H = {}
    self.H[0] = x.reshape(1, -1)
    for i in range(self.nh):
      self.A[i+1] = np.matmul(self.H[i], self.W[i+1]) + self.B[i+1]
      self.H[i+1] = self.sigmoid(self.A[i+1])
    self.A[self.nh+1] = np.matmul(self.H[self.nh], self.W[self.nh+1]) + self.B[self.nh+1]
    self.H[self.nh+1] = self.softmax(self.A[self.nh+1])
    return self.H[self.nh+1]
  
  def predict(self, X):
    Y_pred = []
    for x in X:
      y_pred = self.forward_pass(x)
      Y_pred.append(y_pred)
    return np.array(Y_pred).squeeze()
 
  def grad_sigmoid(self, x):
    return x*(1-x) 
  
  def cross_entropy(self,label,pred):
    yl=np.multiply(pred,label)
    yl=yl[yl!=0]
    yl=-np.log(yl)
    yl=np.mean(yl)
    return yl
 
  def grad(self, x, y):
    self.forward_pass(x)
    self.dW = {}
    self.dB = {}
    self.dH = {}
    self.dA = {}
    L = self.nh + 1
    self.dA[L] = (self.H[L] - y)
    for k in range(L, 0, -1):
      self.dW[k] = np.matmul(self.H[k-1].T, self.dA[k])
      self.dB[k] = self.dA[k]
      self.dH[k-1] = np.matmul(self.dA[k], self.W[k].T)
      self.dA[k-1] = np.multiply(self.dH[k-1], self.grad_sigmoid(self.H[k-1])) 
    
  def fit(self, X, Y, epochs=100, initialize='True', lr=0.01, display_loss=False):
      
    if display_loss:
      loss = {}
      
    if initialize:
      for i in range(self.nh+1):
        self.W[i+1] = np.random.randn(self.sizes[i], self.sizes[i+1])
        self.B[i+1] = np.zeros((1, self.sizes[i+1]))
        
    for epoch in tqdm_notebook(range(epochs), total=epochs, unit="epoch"):
      dW = {}
      dB = {}
      for i in range(self.nh+1):
        dW[i+1] = np.zeros((self.sizes[i], self.sizes[i+1]))
        dB[i+1] = np.zeros((1, self.sizes[i+1]))
      for x, y in zip(X, Y):
        self.grad(x, y)
        for i in range(self.nh+1):
          dW[i+1] += self.dW[i+1]
          dB[i+1] += self.dB[i+1]
                  
      m = X.shape[1]
      for i in range(self.nh+1):
        self.W[i+1] -= (lr* (dW[i+1]/m))
        self.B[i+1] -= (lr * (dB[i+1]/m))
        
      if display_loss:
        Y_pred = self.predict(X) 
        loss[epoch] = self.cross_entropy(Y, Y_pred)
    
    if display_loss:
      plt.plot(list(loss.values()))
      plt.xlabel('Epochs')
      plt.ylabel('CE')
      plt.show()

# %%
ffn = FFSN_MultiClass(X_train_s.shape[1], 2, [8, 4])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
onc = OneHotEncoder()
Y_train_b_o = onc.fit_transform(np.expand_dims(Y_train_b, 1)).toarray()
Y_val_b_o = onc.fit_transform(np.expand_dims(Y_val_b, 1)).toarray()

# %%
ffn.fit(X_train_s, Y_train_b_o, epochs=1000, display_loss=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
ffn.fit(X_train_s, Y_train_b_o, epochs=1000, initialize=False, display_loss=True, lr=0.08)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
Y_val_pred = ffn.predict(X_val_s)
Y_val_pred_b = np.argmax(Y_val_pred, 1)
print(accuracy_score(Y_val_pred_b, Y_val_b))
# Out:
# 0.813953488372093
